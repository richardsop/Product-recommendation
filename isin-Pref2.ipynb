# %%
import pandas as pd
# %matplotlib inline

# %%
train = pd.read_csv("X_test.csv", quoting=0, header=0, delimiter=",")

# %%
train.head()
# Out:
#       User_id                Start_time           City State      Country  \
# 0   988160405  2013-02-01T04:55:00.003Z   (-inf-619.5]   NaN   (0.5-42.5]
# 1   358368837  2012-10-29T00:00:00.001Z  (626.5-688.5]   NaN   (53.5-inf)
# 2  1611204256  2012-09-29T00:00:00.002Z  (626.5-688.5]   NaN   (53.5-inf)
# 3  3122183291  2012-11-04T02:00:00.003Z  (626.5-688.5]   NaN   (53.5-inf)
# 4  1832146052  2012-10-06T03:00:00.003Z  (619.5-626.5]   NaN  (42.5-53.5]
#
#               Lat              Lng  C_1  C_2         C_3     ...      \
# 0    (11.554-inf)  (104.88-104.91]    2    1   (1.5-4.5]     ...
# 1  (-5.159-3.194]   (-61.32-44.77]    1    0  (-inf-1.5]     ...
# 2  (-5.159-3.194]   (-61.32-44.77]    2    1   (1.5-4.5]     ...
# 3  (-5.159-3.194]   (-61.32-44.77]    0    0  (-inf-1.5]     ...
# 4  (3.194-11.531]    (44.77-98.72]    2    0  (-inf-1.5]     ...
#
#    Birthyear  Gender                  JoinedAt            Location Timezone  \
# ...

# %%
#train.groupby("lng").size()

# %%
#train1 = pd.read_csv("Test_train/X_train1_2_BK_2.csv", quoting=0, header=0, delimiter=",")

# %%
train.groupby("Lng").size()
# Out:
# Lng
# (-61.32-44.77]     1230
# (-70.5--61.32]       46
# (-inf--70.5]        696
# (104.88-104.91]     116
# (104.91-107.58]     269
# (107.58-inf)        224
# (44.77-98.72]       418
# (98.72-104.88]       81
# dtype: int64

# %%
co = train.loc[train['C_8'].isin(["(1.5-inf)"])]

# %%
co
# Out:
#           User_id                Start_time           City   State  \
# 18     1171363794  2012-07-18T17:00:00.000Z  (626.5-688.5]      ON
# 21      210296799  2012-12-11T00:00:00.001Z  (626.5-688.5]     NaN
# 22     2541238114  2012-09-27T11:00:00.003Z  (626.5-688.5]     NaN
# 24      631446479  2012-10-26T20:15:00.003Z  (626.5-688.5]     NaN
# 41     3835637004  2012-07-21T16:00:00.000Z   (-inf-619.5]      TX
# 43      249577815  2012-10-13T05:00:00.003Z  (626.5-688.5]     NaN
# 54     3943175229  2012-08-23T22:00:00.003Z  (626.5-688.5]      ON
# 118    3453760477  2012-11-15T22:00:00.003Z   (-inf-619.5]      MD
# 135    3835637004  2012-06-23T23:00:00.000Z  (626.5-688.5]     NaN
# 146    2981133909  2012-10-26T04:00:00.003Z  (626.5-688.5]      CA
# 155    4140744216  2012-12-11T05:00:00.003Z   (-inf-619.5]      CA
# 169     491263047  2012-11-01T01:00:00.003Z  (626.5-688.5]     NaN
# 178     283716061  2012-11-04T08:00:00.003Z   (-inf-619.5]     NaN
# ...

# %%
co.to_csv("C8(1.5-inf).csv", index = False)
